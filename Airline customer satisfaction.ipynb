# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/Users/macbookpro/Downloads/airline customer/test.csv')
df2 = pd.read_csv('/Users/macbookpro/Downloads/airline customer/train.csv')
df = pd.concat([df1,df2], axis =0 , ignore_index = True)

# %%
# remove non useful cloumns: Unamed, id
df = df.iloc[:,2:]

# %%
df
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0       Female     Loyal Customer   52  Business travel       Eco
# 1       Female     Loyal Customer   36  Business travel  Business
# 2         Male  disloyal Customer   20  Business travel       Eco
# 3         Male     Loyal Customer   44  Business travel  Business
# 4       Female     Loyal Customer   49  Business travel       Eco
# ...        ...                ...  ...              ...       ...
# 129875  Female  disloyal Customer   23  Business travel       Eco
# 129876    Male     Loyal Customer   49  Business travel  Business
# 129877    Male  disloyal Customer   30  Business travel  Business
# 129878  Female  disloyal Customer   22  Business travel       Eco
# 129879    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   160                      5
# 1                  2863                      1
# ...

# %%
df.shape
# Out:
# (129880, 23)

# %%
# There is 129880 lines and 23 columns in our dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             129880 non-null  object
#  1   Customer Type                      129880 non-null  object
#  2   Age                                129880 non-null  int64
#  3   Type of Travel                     129880 non-null  object
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Inflight wifi service              129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Ease of Online booking             129880 non-null  int64
#  9   Gate location                      129880 non-null  int64
#  10  Food and drink                     129880 non-null  int64
# ...

# %%
# check the data where is null
null = df[df.isnull().T.any()]
null
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 516     Female     Loyal Customer   21  Personal Travel       Eco
# 656       Male     Loyal Customer    9  Personal Travel       Eco
# 1071      Male  disloyal Customer   25  Business travel       Eco
# 1224      Male     Loyal Customer    7  Personal Travel       Eco
# 1589    Female     Loyal Customer   58  Business travel       Eco
# ...        ...                ...  ...              ...       ...
# 128043    Male     Loyal Customer   49  Personal Travel  Eco Plus
# 128360    Male     Loyal Customer   58  Business travel       Eco
# 128528  Female  disloyal Customer   29  Business travel       Eco
# 128936    Male     Loyal Customer   58  Business travel       Eco
# 129516  Female     Loyal Customer   33  Personal Travel       Eco
#
#         Flight Distance  Inflight wifi service  \
# 516                 632                      1
# 656                 762                      2
# ...

# %%
df.dropna(inplace = True)

# %%
df = pd.get_dummies(df)
df.drop(['Gender_Male','Customer Type_disloyal Customer','Type of Travel_Personal Travel','satisfaction_neutral or dissatisfied'],axis =1,inplace = True)

# %%
df.describe()
# Out:
#                  Age  Flight Distance  Inflight wifi service  \
# count  129487.000000    129487.000000          129487.000000
# mean       39.428761      1190.210662               2.728544
# std        15.117597       997.560954               1.329235
# min         7.000000        31.000000               0.000000
# 25%        27.000000       414.000000               2.000000
# 50%        40.000000       844.000000               3.000000
# 75%        51.000000      1744.000000               4.000000
# max        85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      129487.000000           129487.000000
# mean                            3.057349                2.756786
# std                             1.526787                1.401662
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# ...

# %% [markdown]
# We can see that the passengers average age is around 40 years old, the youngest is 7, and the oldest is 85. 81.7% of customers are loyal customers,and 69% of travel is business travel, which explains 47.9% of class type is buiness class.
#
# The satisfaction rate is 43.45%.
#
# The average flight distence is 1190Km.
#
# Infligt wifi service, ease of online booking are relatively low compare to others.
#
# The average departure delay is 14.64 minutes.
#
# The max of departure delay is 1592minutes, which is around 26.5 hours.
